# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
columns = ['Sepal lenght','Sepal width','Petal Length','Petal Width','Class_labels']
df = pd.read_csv('Iris.csv',names = columns)
df.head(50)
# Out:
#      Sepal lenght   Sepal width   Petal Length   Petal Width Class_labels
# Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa
# 11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.describe()
# Out:
#        Sepal lenght Sepal width Petal Length Petal Width Class_labels
# count           151         151          151         151          151
# unique           36          24           44          23            4
# top             5.0         3.0          1.5         0.2  Iris-setosa
# freq             10          26           14          28           50

# %%
df["Class_labels"].value_counts()
# Out:
# Class_labels
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Species             1
# Name: count, dtype: int64

# %%
sns.FacetGrid(df,hue="Class_labels",height=6).map(plt.scatter,"Petal Width","Sepal width").add_legend()
# Out:
# C:\Users\rajra\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\rajra\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
data = df.values

X = data[:,0:4]
y = data[:,4]
print(y)
# Out:
# ['Species' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y, test_size=0.2)
print(y_test)
print(X_train)
print(y_train)
# Out:
# ['Iris-virginica' 'Iris-virginica' 'Species' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-versicolor' 'Iris-versicolor']
# [['4.4' '3.0' '1.3' '0.2']
#  ['5.1' '3.3' '1.7' '0.5']
#  ['6.0' '3.4' '4.5' '1.6']
#  ['6.5' '3.0' '5.5' '1.8']
#  ['5.0' '3.5' '1.3' '0.3']
#  ['5.5' '4.2' '1.4' '0.2']
#  ['7.2' '3.6' '6.1' '2.5']
#  ['6.3' '3.3' '4.7' '1.6']
#  ['5.3' '3.7' '1.5' '0.2']
#  ['5.0' '3.6' '1.4' '0.2']
#  ['6.1' '2.8' '4.7' '1.2']
#  ['5.1' '3.8' '1.6' '0.2']
#  ['7.7' '2.6' '6.9' '2.3']
#  ['7.0' '3.2' '4.7' '1.4']
#  ['5.0' '2.0' '3.5' '1.0']
#  ['6.8' '3.0' '5.5' '2.1']
# ...

# %%
from sklearn.svm import SVC
model_svc = SVC()
model_svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
prediction1 = model_svc.predict(X_train)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction1)*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 3
#       1 prediction1 = model_svc.predict(X_train)
#       2 from sklearn.metrics import accuracy_score
# ----> 3 print(accuracy_score(y_test,prediction1)*100)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
# ...

# %%
from sklearn.linear_model import LogisticRegression
model_LR=LogisticRegression()
model_LR.fit(X_train,y_train)
model_LR.score(X_train,y_train)
# Out:
# C:\Users\rajra\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9833333333333333

# %%
prediction2 = model_LR.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(X_train,prediction2)*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 prediction2 = model_LR.predict(X_test)
#       2 from sklearn.metrics import accuracy_score
#       3 print(accuracy_score(X_train,prediction2)*100)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:419, in LinearClassifierMixin.predict(self, X)
#     405 """
#     406 Predict class labels for samples in X.
#     407
#    (...)
#     416     Vector containing the class labels for each sample.
#     417 """
#     418 xp, _ = get_namespace(X)
# --> 419 scores = self.decision_function(X)
#     420 if len(scores.shape) == 1:
#     421     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:400, in LinearClassifierMixin.decision_function(self, X)
#     397 check_is_fitted(self)
#     398 xp, _ = get_namespace(X)
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction2))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.64      0.58      0.61        12
# Iris-versicolor       0.25      0.17      0.20        12
#  Iris-virginica       0.08      0.17      0.11         6
#         Species       0.00      0.00      0.00         1
#
#        accuracy                           0.32        31
#       macro avg       0.24      0.23      0.23        31
#    weighted avg       0.36      0.32      0.33        31
# C:\Users\rajra\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn import metrics
print(metrics.confusion_matrix(prediction2,prediction1))
# Out:
# [[11  0  0]
#  [ 0  8  0]
#  [ 0  1 11]]

# %%
print(metrics.classification_report(prediction2,prediction1))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.89      1.00      0.94         8
#  Iris-virginica       1.00      0.92      0.96        12
#
#        accuracy                           0.97        31
#       macro avg       0.96      0.97      0.97        31
#    weighted avg       0.97      0.97      0.97        31
